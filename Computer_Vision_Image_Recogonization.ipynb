# %% [markdown]
# <a href="https://colab.research.google.com/github/Noor-ul-Ayan/DSAI/blob/main/Computer_Vision_Image_Recogonization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls /content/drive/MyDrive/CNNproject/data/image
# Out:
# origin.7z.001  origin.7z.003  origin.7z.005  origin.7z.007
# origin.7z.002  origin.7z.004  origin.7z.006  origin.7z.008

# %%
!7za -y x "/content/drive/MyDrive/CNNproject/data/image/origin.7z.*"
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 8 files, 8113576419 bytes (7738 MiB)
#   0%
# Extracting archive: /content/drive/MyDrive/CNNproject/data/image/origin.7z.001
# --
# Path = /content/drive/MyDrive/CNNproject/data/image/origin.7z.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 8
# Total Physical Size = 8113576419
# ----
# Path = origin.7z
# Size = 8113576419
# --
# Path = origin.7z
# Type = 7z
# Physical Size = 8113576419
# Headers Size = 863607
# Method = LZMA:25
# Solid = +
# Blocks = 2
#
# Everything is Ok
# 100% 106963
# Folders: 1
# Files: 106962
# Size:       8386671768
# Compressed: 8113576419

# %%
import cv2
import numpy as np

# %%
# !cp -r ./origin "/content/drive/MyDrive/CNNproject"
# Out:
# cp: cannot stat './origin': No such file or directory

# %%
label_file_path =r"/content/drive/MyDrive/CNNproject/data/label/label.lst"
images_file_name =r"/content/drive/MyDrive/CNNproject/data/image"
image_path = "/content/drive/MyDrive/CNNproject/origin"

# %%
from os.path import split
import pandas as pd
df_info = pd.read_csv(label_file_path , sep=" " , header=None)
col_names ="image_name face_id_in_image face_box_top face_box_left face_box_right face_box_bottom face_box_cofidence expression_label".split(" ")
df_info.columns = col_names

df_info.head()
# Out:
#             image_name  face_id_in_image  face_box_top  face_box_left  \
# 0  angry_actor_104.jpg                 0            28            113
# 1  angry_actor_109.jpg                 0            31            157
# 2  angry_actor_120.jpg                 1            53             53
# 3   angry_actor_13.jpg                 0            77             51
# 4  angry_actor_132.jpg                 0            95             31
#
#    face_box_right  face_box_bottom  face_box_cofidence  expression_label
# 0             226              141             22.9362                 0
# 1             345              219             50.3056                 0
# 2             372              372             13.9434                 2
# 3             362              388             85.8104                 3
# 4             412              476             82.3948                 0

# %%
df_info.shape
# Out:
# (91793, 8)

# %%
df_sel = df_info[df_info.face_box_cofidence>40]

# %%
import os
ne_path = "/content/drive/MyDrive/CNNproject/origin"
for i,row in df_sel.iterrows():
  img_name =row['image_name']
  com_file = os.path.join(ne_path, img_name)
  image = cv2.imread(com_file)
if image is not None:
  x1 = row["face_box_left"]
  y1 = row["face_box_right"]
  x2 = row["face_box_bottom"]
  y2 = row["face_box_top"]
  crop_images = image[x1:x2, y1:y2]
  label = row["expression label"]
else:
  print(f"error images{img_name}")
# Out:
# error imagessurprised_expression_394.jpg

# %%
preprocessed_images = []
labels = []
def preprocess_image(image_path, x1, y1, x2, y2):
  import os
  image = cv2.imread(os.path.join(label_file_path, images_file_name))
  target_size = (224, 224)
  image = cv2.resize(image, target_size)
  lit = row[y1:y2, x1:x2]
  return lit
  preprocessed_image.append(lit)
  labels.append(label)

# %%
preprocessed_images = np.array(preprocessed_images)
labels = np.array(labels)
preprocessed_images.shape
# Out:
# (0,)

# %%
image_path = "/content/drive/MyDrive/CNNproject/origin"
image = cv.imread("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-f3b06c0e8d1e> in <cell line: 2>()
#       1 image_path = "/content/drive/MyDrive/CNNproject/origin"
# ----> 2 image = cv.imread("")
#
# NameError: name 'cv' is not defined
